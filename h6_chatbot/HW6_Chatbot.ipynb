# %% [markdown]
# # HW6 Coding - Chatbot
#
# In this assignment, we will use Seq2Seq with Attention to implement a simple generative chatbot. The outline of this notebook is very similar to HW5. The dataset consists of dialogues from the TV show Friends. Dialogues were scraped from [here](https://www.livesinabox.com/friends/scripts.shtml). Due to the noisy nature of the dataset, your models may not learn too well and will require some hyperparameter tuning. However, please note that a very-well tuned model is not the goal of this assignment. The goal is to experiment with different settings and provide analysis in your write-up. Furthermore, we will include checkpoints on Gradescope so you can check your model and dataloader implementations.

# %%
# install requirements
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: notebook in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 1)) (6.4.6)
# Requirement already satisfied: numpy in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 2)) (1.21.2)
# Requirement already satisfied: pandas in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 3)) (1.3.2)
# Requirement already satisfied: torch in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 4)) (1.10.0)
# Requirement already satisfied: torchvision in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 5)) (0.11.1)
# Requirement already satisfied: torchtext in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 6)) (0.11.0)
# Requirement already satisfied: matplotlib in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 7)) (3.4.3)
# Requirement already satisfied: gradescope-utils in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: ddt in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 10)) (1.4.4)
# Requirement already satisfied: Pillow in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 11)) (8.3.1)
# Requirement already satisfied: tqdm in /home/andre/miniconda3/lib/python3.9/site-packages (from -r requirements.txt (line 12)) (4.61.2)
# Requirement already satisfied: terminado>=0.8.3 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (0.12.1)
# Requirement already satisfied: ipykernel in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (6.2.0)
# Requirement already satisfied: ipython-genutils in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: pyzmq>=17 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (22.2.1)
# Requirement already satisfied: argon2-cffi in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (21.1.0)
# Requirement already satisfied: jupyter-core>=4.6.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: jupyter-client>=5.3.4 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (7.0.1)
# Requirement already satisfied: tornado>=6.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (6.1)
# Requirement already satisfied: jinja2 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: nest-asyncio>=1.5 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (1.5.1)
# Requirement already satisfied: Send2Trash>=1.8.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (1.8.0)
# Requirement already satisfied: prometheus-client in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (0.12.0)
# Requirement already satisfied: nbformat in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (5.1.3)
# Requirement already satisfied: traitlets>=4.2.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (5.0.5)
# Requirement already satisfied: nbconvert in /home/andre/miniconda3/lib/python3.9/site-packages (from notebook->-r requirements.txt (line 1)) (6.3.0)
# Requirement already satisfied: pytz>=2017.3 in /home/andre/miniconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2021.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/andre/miniconda3/lib/python3.9/site-packages (from pandas->-r requirements.txt (line 3)) (2.8.2)
# Requirement already satisfied: typing-extensions in /home/andre/miniconda3/lib/python3.9/site-packages (from torch->-r requirements.txt (line 4)) (3.10.0.2)
# Requirement already satisfied: requests in /home/andre/miniconda3/lib/python3.9/site-packages (from torchtext->-r requirements.txt (line 6)) (2.25.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 7)) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 7)) (2.4.7)
# Requirement already satisfied: cycler>=0.10 in /home/andre/miniconda3/lib/python3.9/site-packages (from matplotlib->-r requirements.txt (line 7)) (0.10.0)
# Requirement already satisfied: six in /home/andre/miniconda3/lib/python3.9/site-packages (from cycler>=0.10->matplotlib->-r requirements.txt (line 7)) (1.16.0)
# Requirement already satisfied: entrypoints in /home/andre/miniconda3/lib/python3.9/site-packages (from jupyter-client>=5.3.4->notebook->-r requirements.txt (line 1)) (0.3)
# Requirement already satisfied: ptyprocess in /home/andre/miniconda3/lib/python3.9/site-packages (from terminado>=0.8.3->notebook->-r requirements.txt (line 1)) (0.7.0)
# Requirement already satisfied: cffi>=1.0.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from argon2-cffi->notebook->-r requirements.txt (line 1)) (1.14.6)
# Requirement already satisfied: pycparser in /home/andre/miniconda3/lib/python3.9/site-packages (from cffi>=1.0.0->argon2-cffi->notebook->-r requirements.txt (line 1)) (2.20)
# Requirement already satisfied: matplotlib-inline<0.2.0,>=0.1.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipykernel->notebook->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: debugpy<2.0,>=1.0.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipykernel->notebook->-r requirements.txt (line 1)) (1.4.1)
# Requirement already satisfied: ipython<8.0,>=7.23.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipykernel->notebook->-r requirements.txt (line 1)) (7.26.0)
# Requirement already satisfied: jedi>=0.16 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (3.0.17)
# Requirement already satisfied: pexpect>4.3 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (4.8.0)
# Requirement already satisfied: pickleshare in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (0.7.5)
# Requirement already satisfied: pygments in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (2.10.0)
# Requirement already satisfied: setuptools>=18.5 in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (52.0.0.post20210125)
# Requirement already satisfied: decorator in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (5.0.9)
# Requirement already satisfied: backcall in /home/andre/miniconda3/lib/python3.9/site-packages (from ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from jedi>=0.16->ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (0.8.2)
# Requirement already satisfied: wcwidth in /home/andre/miniconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython<8.0,>=7.23.1->ipykernel->notebook->-r requirements.txt (line 1)) (0.2.5)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from jinja2->notebook->-r requirements.txt (line 1)) (2.0.1)
# Requirement already satisfied: testpath in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (0.5.0)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (0.5.9)
# Requirement already satisfied: mistune<2,>=0.8.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (0.8.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (1.5.0)
# Requirement already satisfied: defusedxml in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (0.1.2)
# Requirement already satisfied: bleach in /home/andre/miniconda3/lib/python3.9/site-packages (from nbconvert->notebook->-r requirements.txt (line 1)) (4.1.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /home/andre/miniconda3/lib/python3.9/site-packages (from nbformat->notebook->-r requirements.txt (line 1)) (4.2.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 1)) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /home/andre/miniconda3/lib/python3.9/site-packages (from jsonschema!=2.5.0,>=2.4->nbformat->notebook->-r requirements.txt (line 1)) (21.2.0)
# Requirement already satisfied: packaging in /home/andre/miniconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook->-r requirements.txt (line 1)) (21.3)
# Requirement already satisfied: webencodings in /home/andre/miniconda3/lib/python3.9/site-packages (from bleach->nbconvert->notebook->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: chardet<5,>=3.0.2 in /home/andre/miniconda3/lib/python3.9/site-packages (from requests->torchtext->-r requirements.txt (line 6)) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /home/andre/miniconda3/lib/python3.9/site-packages (from requests->torchtext->-r requirements.txt (line 6)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /home/andre/miniconda3/lib/python3.9/site-packages (from requests->torchtext->-r requirements.txt (line 6)) (2021.5.30)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/andre/miniconda3/lib/python3.9/site-packages (from requests->torchtext->-r requirements.txt (line 6)) (1.26.6)
# WARNING: You are using pip version 21.2.4; however, version 21.3.1 is available.
# You should consider upgrading via the '/home/andre/miniconda3/bin/python3 -m pip install --upgrade pip' command.

# %%
# Imports
import re
import random

import torch
import torch.nn as nn
from torch import optim
import torch.nn.functional as F
from torchtext.data.metrics import bleu_score
import pandas as pd
import time
import numpy as np
import math
from tqdm import tqdm
tqdm.pandas()

# try %matplotlib notebook (if following doesn't work)
# %matplotlib inline
import matplotlib.pyplot as plt

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from dataset import *
from model import *

# %% [markdown]
# # Read and Preprocess *Friends* Scripts

# %%
data_df = pd.read_pickle('friends_subtitles.pkl')

# %% [markdown]
# Look at the data

# %%
print(data_df.shape)
data_df.sample(5)
# Out:
# (76114, 4)
#       episode                                   title    character  \
# 55498     805              The One With Rachel's Date         ross
# 74470    1016  The One With Rachel's Going Away Party       monica
# 32833     417              The One With The Free Porn         ross
# 17641     220           The One Where Old Yeller Dies  carol,susan
# 72415    1009           The One With The Birth Mother         joey
#
#                                                 dialogue
# 55498                  [well, ,, how, was, the, date, ?]
# 74470                                   [oh, my, god, !]
# 32833  [okay, !, okay, !, but, if, she, doesn, ’, t, ...
# 17641               [great, ., that, would, be, fine, .]
# 72415      [looks, like, someone, is, the, ladies, !, !]

# %%
# dialogue length distribution
token_lens = data_df.dialogue.progress_apply(lambda x: len(x))
token_lens.describe(percentiles=[0.5, 0.75, 0.90])
# Out:
# 100%|██████████| 76114/76114 [00:00<00:00, 914716.64it/s]
# count    76114.000000
# mean        14.003784
# std         15.896689
# min          0.000000
# 50%         10.000000
# 75%         18.000000
# 90%         30.000000
# max       1157.000000
# Name: dialogue, dtype: float64

# %%
len_vcs = (token_lens < 20).value_counts()
print(len_vcs)
len_vcs.loc[True] / len_vcs.sum()
# Out:
# True     58964
# False    17150
# Name: dialogue, dtype: int64
# 0.7746800851354547

# %%
## Visualize token_lens with either of following plots
# token_lens.value_counts().sort_index().plot.line()
# token_lens.plot.hist(bins=200)
token_lens.plot.density()
plt.xlabel('# of Tokens')
plt.xlim(left=0, right=60)
# Out:
# (0.0, 60.0)

# %%
# pick MAX LENGTH 
MAX_LENGTH = 30 # 90th percentile (smaller for faster training)

# %% [markdown]
# ## Preprocess data

# %%
# Initialize data hyperparams
MAIN_CHARACTERS = ['ross', 'rachel', 'monica', 'phoebe', 'chandler', 'phoebe']
OTHER_CHARS = 'other_char'
CONTEXTS = [1, 3]

# %%
data_df.sample(5)
# Out:
#       episode                               title character  \
# 42888     606              The One The Last Night    rachel
# 43973     611   The One With The Apothecary Table    phoebe
# 8747      122              The One The Ick Factor    santos
# 2305      107           The One With The Blackout    rachel
# 72034    1008  The One With The Late Thanksgiving    phoebe
#
#                                                 dialogue
# 42888  [but, honey, ,, i, think, she, ’, s, moving, i...
# 43973  [ooh, ,, what, a, great, table, !, where-where...
# 8747                            [hello, ,, mr., bing, .]
# 2305               [oh, ross, ,, you, 're, so, great, .]
# 72034  [well, ,, she, 's, gon, na, look, all, washed,...

# %%
# filter characters to replace any non-main characters to OTHER
def keep_only_main(character):
    # split if contains multiple characters
    characters = character.split(',')
    for i, char in enumerate(characters):
        if char not in MAIN_CHARACTERS: characters[i] = OTHER_CHARS
    return ','.join(characters)

data_df.loc[:, 'character'] = data_df.character.progress_apply(keep_only_main)
data_df.sample(5)
# Out:
# 100%|██████████| 76114/76114 [00:00<00:00, 901191.41it/s]
#       episode                              title   character  \
# 44482     613       The One With Rachel's Sister      rachel
# 67409     920  The One With The Soap Opera Party      monica
# 63821     918           The One With The Lottery    chandler
# 36836     507        The One Where Ross Moves In      phoebe
# 18443     223       The One With The Chicken Pox  other_char
#
#                                                 dialogue
# 44482  [oh, !, did, you, hear, that, ?, !, my, dad, ’...
# 67409  [that, 's, different, !, i, was, drunk, and, s...
# 63821  [ok, ,, so, now, that, you, 're, in, ,, what, ...
# 36836                                          [okay, .]
# 18443  [hey, chandler, ,, here, 's, this, morning, 's...

# %%
# get contexts for samples (context only has previous messages separated by SEP token)
def get_contexts(row):
    row_idx = row.name
    episode = row.episode
    context_dialogues = []
    for ctx in CONTEXTS:
#         print("context", ctx, f'| range: {(row_idx-ctx, row_idx)}', list(range(row_idx-ctx, row_idx, -1)))
        diags = []
        for ctx_idx in range(row_idx-ctx, row_idx, 1):
#             print(ctx_idx, ctx_idx < 0)
            if ctx_idx < 0: continue
            diag_row = data_df.iloc[ctx_idx]
#             print(diag_row.episode, diag_row.episode != episode)
            if diag_row.episode != episode: continue
#             print((diag_row.filt_char, diag_row.diag_tok))
#             diags.append((diag_row.filt_char, diag_row.diag_tok))
            diags += diag_row.dialogue + ['SEP']
        # remove last 'SEP' added
        if len(diags) > 0: diags = diags[:-1]
        context_dialogues.append(diags if len(diags) != 0 else None)
    return pd.Series(context_dialogues, index=[f'ctx_{c}' for c in CONTEXTS])

data_df[[f'ctx_{c}' for c in CONTEXTS]] = data_df.progress_apply(get_contexts, axis=1)
# Out:
# 100%|██████████| 76114/76114 [00:35<00:00, 2114.61it/s]

# %%
# check contexts
data_df.iloc[303:308]
# Out:
#     episode                                 title   character  \
# 303     101           The Pilot-The Uncut Version      rachel
# 304     101           The Pilot-The Uncut Version    chandler
# 305     102  The One With The Sonogram At the End      monica
# 306     102  The One With The Sonogram At the End  other_char
# 307     102  The One With The Sonogram At the End      phoebe
#
#                                               dialogue  \
# 303  [ugh, ., excuse, me, ,, could, you, give, this...
# 304  [okay, ,, so, ,, i, 'm, in, las, vegas, ..., i...
# 305  [what, you, guys, do, n't, understand, is, ,, ...
# 306         [yeah, ,, right, !, ......., y'serious, ?]
# 307                                   [oh, ,, yeah, !]
#
#                                                  ctx_1  \
# 303                 [ahh, ,, miss, ?, more, coffee, ?]
# 304  [ugh, ., excuse, me, ,, could, you, give, this...
# 305                                               None
# 306  [what, you, guys, do, n't, understand, is, ,, ...
# 307         [yeah, ,, right, !, ......., y'serious, ?]
#
#                                                  ctx_3
# 303  [yeah, ., yeah, ,, i, 'll, have, a, cup, of, c...
# 304  [kids, ,, new, dream, ..., i, 'm, in, las, veg...
# 305                                               None
# 306  [what, you, guys, do, n't, understand, is, ,, ...
# 307  [what, you, guys, do, n't, understand, is, ,, ...

# %%
# remove rows with no previous messages (ctx_1 is None)
data_df = data_df[~data_df.ctx_1.isna()]
data_df.shape
# Out:
# (75854, 6)

# %%
# split rows with multiple characters into individual rows
print("previously", data_df.shape)
cols = data_df.columns.tolist()
data = []
for i, row in tqdm(data_df.iterrows(), total=len(data_df)):
    thisrow = row.copy()
    chars = thisrow.character.split(',')
    for c in chars:
        thisrow.character = c
        data.append(thisrow.tolist())

data_df = pd.DataFrame(data, columns=cols)
print('after', data_df.shape)
# Out:
# previously (75854, 6)
# 100%|██████████| 75854/75854 [00:06<00:00, 11879.46it/s]
# after (76209, 6)

# %%
# remove rows where dialogue is empty []
def isEmpty(dialogue):
    if len(dialogue) == 0:
        return True
    return False
diags = data_df.dialogue.progress_apply(isEmpty)
# rewrite data_df and don't include where diags was true
data_df = data_df[~diags]
data_df = data_df.reset_index(drop=True)
data_df
# Out:
# 100%|██████████| 76209/76209 [00:00<00:00, 944961.77it/s]
#       episode                        title   character  \
# 0         101  The Pilot-The Uncut Version  other_char
# 1         101  The Pilot-The Uncut Version    chandler
# 2         101  The Pilot-The Uncut Version      phoebe
# 3         101  The Pilot-The Uncut Version      phoebe
# 4         101  The Pilot-The Uncut Version      monica
# ...       ...                          ...         ...
# 76162     The      Stuff You've Never Seen  other_char
# 76163     The      Stuff You've Never Seen  other_char
# 76164     The      Stuff You've Never Seen        ross
# 76165     The      Stuff You've Never Seen  other_char
# 76166     The      Stuff You've Never Seen  other_char
#
#                                                 dialogue  \
# 0      [c'mon, ,, you, 're, going, out, with, the, gu...
# 1      [all, right, joey, ,, be, nice, ., so, does, h...
# 2                     [wait, ,, does, he, eat, chalk, ?]
# 3      [just, ,, 'cause, ,, i, do, n't, want, her, to...
# 4      [okay, ,, everybody, relax, ., this, is, not, ...
# ...                                                  ...
# 76162              [i, ’, m, sorry, ,, i, messed, up, .]
# 76163  [i, ’, ll, do, it, again, and, again, if, you,...
# 76164                     [no-no, !, i, ’, ll-i, ’, ll…]
# 76165                           [that, is, too, much, !]
# 76166                   [let, me, start, that, again, .]
#
#                                                    ctx_1  \
# 0      [there, 's, nothing, to, tell, !, he, 's, just...
# 1      [c'mon, ,, you, 're, going, out, with, the, gu...
# 2      [all, right, joey, ,, be, nice, ., so, does, h...
# 3                     [wait, ,, does, he, eat, chalk, ?]
# 4      [just, ,, 'cause, ,, i, do, n't, want, her, to...
# ...                                                  ...
# 76162                        [i, think, you, got, it, !]
# 76163              [i, ’, m, sorry, ,, i, messed, up, .]
# 76164  [i, ’, ll, do, it, again, and, again, if, you,...
# 76165                     [no-no, !, i, ’, ll-i, ’, ll…]
# 76166                           [that, is, too, much, !]
#
#                                                    ctx_3
# 0      [there, 's, nothing, to, tell, !, he, 's, just...
# 1      [there, 's, nothing, to, tell, !, he, 's, just...
# 2      [there, 's, nothing, to, tell, !, he, 's, just...
# 3      [c'mon, ,, you, 're, going, out, with, the, gu...
# 4      [all, right, joey, ,, be, nice, ., so, does, h...
# ...                                                  ...
# 76162  [oh, what, are, doing, ?, !, SEP, you, ’, re, ...
# 76163  [you, ’, re, still, a, tiny, bit, on, fire, th...
# 76164  [i, think, you, got, it, !, SEP, i, ’, m, sorr...
# 76165  [i, ’, m, sorry, ,, i, messed, up, ., SEP, i, ...
# 76166  [i, ’, ll, do, it, again, and, again, if, you,...
#
# [76167 rows x 6 columns]

# %% [markdown]
# ## Choose two characters
#
# We will choose two characters' dialogues to learn a chatbot with. With the same Seq2Seq with Attention architecture from HW5, we will try to associate characters' persona by using embeddings of their persona as first input to the decoder instead of the SOS_token used previously.

# %%
# view character and dialogue counts
data_df.character.value_counts()
# Out:
# other_char    22620
# ross          11590
# rachel        11522
# monica        10732
# chandler      10448
# phoebe         9255
# Name: character, dtype: int64

# %%
CHOSEN_CHARACTERS = {"rachel", "phoebe"} # which characters to build chatbot for
print(data_df)
# Out:
#       episode                        title   character  \
# 0         101  The Pilot-The Uncut Version  other_char
# 1         101  The Pilot-The Uncut Version    chandler
# 2         101  The Pilot-The Uncut Version      phoebe
# 3         101  The Pilot-The Uncut Version      phoebe
# 4         101  The Pilot-The Uncut Version      monica
# ...       ...                          ...         ...
# 76162     The      Stuff You've Never Seen  other_char
# 76163     The      Stuff You've Never Seen  other_char
# 76164     The      Stuff You've Never Seen        ross
# 76165     The      Stuff You've Never Seen  other_char
# 76166     The      Stuff You've Never Seen  other_char
#
#                                                 dialogue  \
# 0      [c'mon, ,, you, 're, going, out, with, the, gu...
# 1      [all, right, joey, ,, be, nice, ., so, does, h...
# 2                     [wait, ,, does, he, eat, chalk, ?]
# 3      [just, ,, 'cause, ,, i, do, n't, want, her, to...
# 4      [okay, ,, everybody, relax, ., this, is, not, ...
# ...                                                  ...
# 76162              [i, ’, m, sorry, ,, i, messed, up, .]
# 76163  [i, ’, ll, do, it, again, and, again, if, you,...
# 76164                     [no-no, !, i, ’, ll-i, ’, ll…]
# 76165                           [that, is, too, much, !]
# 76166                   [let, me, start, that, again, .]
#
#                                                    ctx_1  \
# 0      [there, 's, nothing, to, tell, !, he, 's, just...
# 1      [c'mon, ,, you, 're, going, out, with, the, gu...
# 2      [all, right, joey, ,, be, nice, ., so, does, h...
# 3                     [wait, ,, does, he, eat, chalk, ?]
# 4      [just, ,, 'cause, ,, i, do, n't, want, her, to...
# ...                                                  ...
# 76162                        [i, think, you, got, it, !]
# 76163              [i, ’, m, sorry, ,, i, messed, up, .]
# 76164  [i, ’, ll, do, it, again, and, again, if, you,...
# 76165                     [no-no, !, i, ’, ll-i, ’, ll…]
# 76166                           [that, is, too, much, !]
#
#                                                    ctx_3
# 0      [there, 's, nothing, to, tell, !, he, 's, just...
# 1      [there, 's, nothing, to, tell, !, he, 's, just...
# 2      [there, 's, nothing, to, tell, !, he, 's, just...
# 3      [c'mon, ,, you, 're, going, out, with, the, gu...
# 4      [all, right, joey, ,, be, nice, ., so, does, h...
# ...                                                  ...
# 76162  [oh, what, are, doing, ?, !, SEP, you, ’, re, ...
# 76163  [you, ’, re, still, a, tiny, bit, on, fire, th...
# 76164  [i, think, you, got, it, !, SEP, i, ’, m, sorr...
# 76165  [i, ’, m, sorry, ,, i, messed, up, ., SEP, i, ...
# 76166  [i, ’, ll, do, it, again, and, again, if, you,...
#
# [76167 rows x 6 columns]

# %%
filtered_df = data_df[data_df.character.isin(CHOSEN_CHARACTERS)].reset_index(drop=True)
filtered_df
# Out:
#       episode                        title character  \
# 0         101  The Pilot-The Uncut Version    phoebe
# 1         101  The Pilot-The Uncut Version    phoebe
# 2         101  The Pilot-The Uncut Version    phoebe
# 3         101  The Pilot-The Uncut Version    phoebe
# 4         101  The Pilot-The Uncut Version    phoebe
# ...       ...                          ...       ...
# 20772     The      Stuff You've Never Seen    phoebe
# 20773     The      Stuff You've Never Seen    phoebe
# 20774     The      Stuff You've Never Seen    phoebe
# 20775     The      Stuff You've Never Seen    rachel
# 20776     The      Stuff You've Never Seen    phoebe
#
#                                                 dialogue  \
# 0                     [wait, ,, does, he, eat, chalk, ?]
# 1      [just, ,, 'cause, ,, i, do, n't, want, her, to...
# 2                                                [no, .]
# 3                                        [ooh, !, oh, !]
# 4                                [fine, !, be, murky, !]
# ...                                                  ...
# 20772                            [what, do, i, smell, ?]
# 20773                            [what, do, i, smell, ?]
# 20774  [oh, ,, sweet, je——sus, !, oh, !, monica, ,, t...
# 20775                                  [i, ’, m, sorry…]
# 20776                        [thank, you, my, babies, .]
#
#                                                    ctx_1  \
# 0      [all, right, joey, ,, be, nice, ., so, does, h...
# 1                     [wait, ,, does, he, eat, chalk, ?]
# 2                           [never, had, that, dream, .]
# 3                                            [thanks, .]
# 4      [no, ,, no, do, n't, !, stop, cleansing, my, a...
# ...                                                  ...
# 20772  [and, then, it, was, like, four, takes, later,...
# 20773                                     [le, blanc, .]
# 20774                  [you, see, ,, i, don, ’, t, say—]
# 20775                                          [joey, ?]
# 20776  [well, thank, you, for, coming, here, ,, it, ’...
#
#                                                    ctx_3
# 0      [there, 's, nothing, to, tell, !, he, 's, just...
# 1      [c'mon, ,, you, 're, going, out, with, the, gu...
# 2      [instead, of, ..., ?, SEP, that, 's, right, .,...
# 3      [ohh, ., SEP, let, me, get, you, some, coffee,...
# 4      [thanks, ., SEP, ooh, !, oh, !, SEP, no, ,, no...
# ...                                                  ...
# 20772  [what, do, i, smell, ?, SEP, sorry, ., SEP, an...
# 20773  [and, then, it, was, like, four, takes, later,...
# 20774  [you-you, mentally, make, a, flag, on, it, and...
# 20775  [whoa, !, she, ’, s, purty, !, SEP, oh, yeah, ...
# 20776  [well, thank, you, so, much, ., SEP, thank, yo...
#
# [20777 rows x 6 columns]

# %% [markdown]
# ### Implement
#
# We will now create create train / val splits. Please go to **`dataset.py`** and finish implementation for the function **`split_train_val`**. Make sure to also implement *shuffle* functionality if `shuffle=True`.

# %%
train_df, val_df = split_train_val(filtered_df, props=[0.85, 0.15], shuffle=True)
# view train val size
print(train_df.shape, val_df.shape)
# verify implementation
#assert train_df.shape[0] == 17660, "split is not implemented properly"
#assert val_df.shape[0] == 3117, "split is not implemented properly"
# Out:
# (17660, 6) (3117, 6)

# %% [markdown]
# Initialize vocabulary for input and target language vocabulary from train_df using the `initLang` function in `dataset.py`. This is already implemented for you. We will start with context size **1** (column = 'ctx_1')

# %%
context_column = 'ctx_3'
target_column = 'dialogue'
lang = initLang(characters=CHOSEN_CHARACTERS, df = train_df[[target_column, context_column]])
# Out:
# characters added | total_vocab_size: 5
# initializing: dialogue | total_vocab_size: 9101
# initializing: ctx_3 | total_vocab_size: 15005

# %%
lang.trim(2, keep=CHOSEN_CHARACTERS)
# Out:
# keep_words 12485 / 15005 = 0.8321

# %%
# make sure chosen characters are still in the vocabulary
[char in lang.word2index for char in CHOSEN_CHARACTERS]
# Out:
# [True, True]

# %% [markdown]
# ### Implement
#
# Create dataloaders for train, val and test data using `lang` variable defined above. Please go to `dataset.py` and finish the implementation for `Chatbot_Dataset.__getitem__()` in

# %%
train_dataloader = create_data_loader(df = train_df, 
                                      lang = lang,
                                      context_col = context_column,
                                      target_col = target_column,
                                      MAX_LEN = MAX_LENGTH,
                                      shuffle=True)

val_dataloader = create_data_loader(df = val_df, 
                                      lang = lang,
                                      context_col = context_column,
                                      target_col = target_column,
                                      MAX_LEN = MAX_LENGTH,
                                      shuffle=True)

# %%
# view sample from dataloader
sample = next(iter(train_dataloader))
print('input_tensor', sample['input_tensor'], sample['input_tensor'].shape)
print('persona_tensor', sample['persona_tensor'], sample['persona_tensor'].shape)
print('target_tensor', sample['target_tensor'], sample['target_tensor'].shape)
# Out:
# input_tensor tensor([[ 363,    6,   25,    6,   39,  125,   87,   44,  121,   97,  224, 3623,
#            99,   11,   14, 1819,   19, 3644,   28,    3,   39, 1819,   19,  142,
#            28,   51,   39, 1675,   11,    1]]) torch.Size([1, 30])
# persona_tensor tensor([[3]]) torch.Size([1, 1])
# target_tensor tensor([[ 376,    6,  334,   14,  143,  174, 1675,   28,   38, 1000,    6,  546,
#            55,   15,   16, 3645,   55,   28,  114, 3646,  229, 3647,    6,   38,
#             8,   63,   16, 3623,   99,    1]]) torch.Size([1, 30])

# %% [markdown]
# # Model Seq2Seq with Attention
#
# Here, we reuse the simple encoder-decoder from last homework. Both encoder and decoders are RNNs (Gated Recurrent Units (GRU)). In the following section, you will implement `EncoderRNN` and `AttnDecoderRNN`. The encoder process previous context messages and provides it's outputs at every time step and last hidden state to the decoder. The decoder's first input with the a character's persona as well as outputs/hidden state from the encoder.
#
# **Relevant work**:
# - [Sequence to Sequence Learnign with Neural Networks](https://arxiv.org/pdf/1409.3215.pdf)
# - [Learning Phrase Representations using RNN Encoder-Decoder for Statistical Machine Translation]

# %% [markdown]
# ### EncoderRNN and AttnDecoderRNN
#
# Please **implement** the `__init__` and `__forward__` functions of the `EncoderRNN` and `AttnDecoderRNN` in `model.py`

# %%
# Helper functions used to keep track of time
def asMinutes(s):
    m = math.floor(s / 60)
    s -= m * 60
    return '%dm %ds' % (m, s)


def timeSince(since, percent):
    now = time.time()
    s = now - since
    es = s / (percent)
    rs = es - s
    return '%s (- %s)' % (asMinutes(s), asMinutes(rs))

# %% [markdown]
# ### Training the Seq2Seq with Attention
#
# Please **implement** the following `train` function which process just one sample. The train loop is implemented for you after this cell. The template initializes relevant variables. You will implement for loops to step through encoder with `input_tensor` and decoder loop to step through `target_tensor` (with **and** without teacher forcing). The decoder loop is where you will also calculate the loss using the criterion.
#
# If you are unsure what arguments are being passed to the `train` function, please view the `train_iters` and `eval_iters` functions in the cells after.

# %%
teacher_forcing_ratio = 0.5

def train(input_tensor, target_tensor, persona_tensor, encoder, decoder, encoder_optimizer, decoder_optimizer, criterion, max_length=MAX_LENGTH):
    # initialize encoder hidden state
    encoder_hidden = encoder.initHidden()

    encoder_optimizer.zero_grad()
    decoder_optimizer.zero_grad()
    
    input_length = input_tensor.size()[0]
    target_length = target_tensor.size()[0]
    loss = 0
    
    # this time we need to keep trak of encoder outputs
    encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
    
    # Process input input_tensor (one token at a time with a for loop)
    ## YOUR CODE STARTS HERE (~3 lines of code) ##
    # for loop header
    for ei in range(input_length):
        # call encoder with input_tensor[ei] and encoder's hidden vector
        encoder_output, encoder_hidden = encoder(input_tensor[ei], encoder_hidden)
        # save encoder output in encoder_outputs
        encoder_outputs[ei] = encoder_output[0, 0]

    ## YOUR CODE ENDS HERE ##

    # Start decoder's input with character (persona) token
    decoder_input = persona_tensor

    # initialize decoder hidden state as encoder's final hidden state
    decoder_hidden = encoder_hidden

    # decide whether to use teacher forcing 
    use_teacher_forcing = True if random.random() < teacher_forcing_ratio else False

    if use_teacher_forcing:
        # Teacher forcing: Feed the target as the next input
        ## YOUR CODE STARTS HERE (~4 lines of code) ##
        # for loop header to loop through target_tensor
        for di in range(target_length):
            # call decoder with decoder_input, decoder_hidden and encoder_outputs. 
            #     make sure to reset decoder_hidden with the new hidden state returned
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)

            # calculate loss using decoder's output and corresponding target_tensor[di]
            #     the criterion used is a negative log likelihood loss (NLLLoss)
            loss += criterion(decoder_output, target_tensor[di])

            # (Teacher forcing) set next decoder input as target_tensor[di]
            decoder_input = target_tensor[di] 
        ## YOUR CODE ENDS HERE ##

    else:
        # Without teacher forcing: use its own predictions as the next input
        ## YOUR CODE STARTS HERE (~5-7 lines of code) ##
        # for loop header to loop through target_tensor
        for di in range(target_length):
            
            # call decoder same as above
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)
            topv, topi = decoder_output.topk(1)
            decoder_input = topi.squeeze().detach()

            # calculate loss same as above
            loss += criterion(decoder_output, target_tensor[di])
            # set next decoder input as argmax of decoder's output

            # if new decoder_input is EOS_token: break
            if decoder_input.item() == EOS_token:
                break

        ## YOUR CODE ENDS HERE ##

    loss.backward()

    encoder_optimizer.step()
    decoder_optimizer.step()

    return loss.item() / target_length

# %% [markdown]
# Next, please **implement** the `evaluate` function in the next cell. The process will be the same as `train`, except you will not use teacher forcing when stepping through the decoder.

# %%
# evaluate
def evaluate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_length = input_tensor.size()[0]
        if target_tensor is not None:
            target_length = target_tensor.size()[0]
        else:
            target_length = max_length
        encoder_hidden = encoder.initHidden()
        loss = 0
        
        # this time we need to keep trak of encoder outputs
        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        
        # Process input input_tensor (one token at a time with a for loop)
        ## YOUR CODE STARTS HERE (~3 lines of code) ##
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        ## YOUR CODE ENDS HERE ##

        # Start decoder's input with <SOS> token
        decoder_input = persona_tensor

        # initialize decoder hidden state as encoder's final hidden state
        decoder_hidden = encoder_hidden

        decoded_indices = []
        decoded_words = []
        # keep track of decoder attention for analysis later
        decoder_attentions = torch.zeros(max_length, max_length)

        # Run decoder starting with encoder's context (decoder_hidden)
        #     without using teacher forcing: use its own predictions as the next input
        ## YOUR CODE STARTS HERE (~5-7 lines of code) ##
        # for loop header to loop through target_tensor
        for di in range(target_length):
            # call decoder
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)

            # save decoder attention in decoder_attentions
            decoder_attentions[di] = decoder_attention.data

            # calculate loss same as above (if target_tensor exists)
            loss += criterion(decoder_output, target_tensor[di])


            # set next decoder input as argmax of decoder's output
            topv, topi = decoder_output.data.topk(1)
            decoder_input = topi.squeeze().detach()

            # append outputted index to decoded_indices

            # if new decoder_input is EOS_token: break
            if topi.item() == EOS_token:
                decoded_indices.append(EOS_token)
                break
            else:
                decoded_indices.append(topi.item())
        ## YOUR CODE ENDS HERE ##
        decoded_words = lang.getWordsFromIndices(decoded_indices)

        return decoded_words, int(loss) / len(decoded_words), decoder_attentions[:di + 1]

def generate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion, max_length=MAX_LENGTH):
    with torch.no_grad():
        input_length = input_tensor.size()[0]
        if target_tensor is not None:
            target_length = target_tensor.size()[0]
        else:
            target_length = max_length
        encoder_hidden = encoder.initHidden()
        loss = 0
        
        # this time we need to keep trak of encoder outputs
        encoder_outputs = torch.zeros(max_length, encoder.hidden_size, device=device)
        
        # Process input input_tensor (one token at a time with a for loop)
        ## YOUR CODE STARTS HERE (~3 lines of code) ##
        for ei in range(input_length):
            encoder_output, encoder_hidden = encoder(input_tensor[ei],
                                                     encoder_hidden)
            encoder_outputs[ei] += encoder_output[0, 0]

        ## YOUR CODE ENDS HERE ##

        # Start decoder's input with <SOS> token
        decoder_input = persona_tensor

        # initialize decoder hidden state as encoder's final hidden state
        decoder_hidden = encoder_hidden

        decoded_indices = []
        decoded_words = []
        # keep track of decoder attention for analysis later
        decoder_attentions = torch.zeros(max_length, max_length)

        # Run decoder starting with encoder's context (decoder_hidden)
        #     without using teacher forcing: use its own predictions as the next input
        ## YOUR CODE STARTS HERE (~5-7 lines of code) ##
        # for loop header to loop through target_tensor
        for di in range(target_length):
            # call decoder
            decoder_output, decoder_hidden, decoder_attention = decoder(decoder_input, decoder_hidden, encoder_outputs)

            # save decoder attention in decoder_attentions
            decoder_attentions[di] = decoder_attention.data

            # calculate loss same as above (if target_tensor exists)
            # loss += criterion(decoder_output, target_tensor[di])


            # set next decoder input as argmax of decoder's output
            topv, topi = decoder_output.data.topk(1)
            decoder_input = topi.squeeze().detach()

            # append outputted index to decoded_indices

            # if new decoder_input is EOS_token: break
            if topi.item() == EOS_token:
                decoded_indices.append(EOS_token)
                break
            else:
                decoded_indices.append(topi.item())
        ## YOUR CODE ENDS HERE ##
        decoded_words = lang.getWordsFromIndices(decoded_indices)

        return decoded_words#, int(loss) / len(decoded_words), decoder_attentions[:di + 1]

# %% [markdown]
# `trainEvalIters` is implemented for you. Simply review the implementation and run the following cells.

# %%
def createDataFrame(points):
    df = pd.DataFrame(points, columns=['train_loss', 'val_loss', 'blue_scores_val'])
    return df

def evalIters(encoder, decoder, val_dataloader, criterion, num_samples=100):
    if num_samples > len(val_dataloader):
        num_samples = len(val_dataloader)
    
    candidates = [] # predicted output
    references = [] # true targets
    
    total_loss = 0
    for iter, sample in enumerate(val_dataloader):
        if iter > num_samples: break

#         print("Eval Sample:", sample)
        input_tensor = sample['input_tensor'].squeeze().to(device)
        target_tensor = sample['target_tensor'].squeeze().to(device)
        persona_tensor = sample['persona_tensor'].squeeze().to(device)
        
        decoded_out, loss, _ = evaluate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion)
#         print("Loss:", loss)
        candidates.append(decoded_out)
        target_indices = sample['target_tensor'].squeeze().tolist()
        target_words = lang.getWordsFromIndices(target_indices)
#         print(">", lang.getWordsFromIndices(sample['input_tensor'].squeeze().tolist()))
#         print("=", target_words)
#         print("<", decoded_out)
        references.append([target_words])
        total_loss += loss
    
    return total_loss / num_samples, bleu_score(candidate_corpus=candidates, 
                                                references_corpus=references,
                                                max_n=4)

def trainEvalIters(encoder, decoder, epochs, train_dataloader, val_dataloader, 
                   eval_every=1000, eval_samples=100, learning_rate=0.01):
    start = time.time()
    plot_stats = []
    train_loss_total = 0  # Reset every eval_every

    encoder_optimizer = optim.SGD(encoder.parameters(), lr=learning_rate)
    decoder_optimizer = optim.SGD(decoder.parameters(), lr=learning_rate)

    criterion = nn.NLLLoss()
    num_samples = len(train_dataloader)
    n_iters = epochs * num_samples
    
    for ep in range(epochs):
        for iter, sample in enumerate(train_dataloader):
#             print("Train Sample:", sample)
            input_tensor = sample['input_tensor'].squeeze().to(device)
#             print(input_tensor.shape)
            target_tensor = sample['target_tensor'].squeeze().to(device)
            persona_tensor = sample['persona_tensor'].squeeze().to(device)

            loss = train(input_tensor, target_tensor, persona_tensor, encoder,
                         decoder, encoder_optimizer, decoder_optimizer, criterion)
            train_loss_total += loss
#             print("loss:", loss)

            if (iter + 1) % eval_every == 0:
                train_loss_average = train_loss_total / eval_every
                train_loss_total = 0
                
                # validate model
                eval_loss, bleu_score = evalIters(encoder, decoder, val_dataloader, criterion, num_samples=eval_samples)
                
                curr_iter = ep * num_samples + iter + 1
                print('%s (%d %d%%) Average train loss: %.4f, Average val loss: %.4f ,val BLEU: %.4f' % (timeSince(start, curr_iter / n_iters), curr_iter, curr_iter / n_iters * 100, train_loss_average, eval_loss, bleu_score))

#                 plot_loss_avg = plot_loss_total / plot_every
                plot_stats.append([train_loss_average, eval_loss, bleu_score])
                plot_loss_total = 0

    return createDataFrame(plot_stats)

# %%
hidden_size = 512
n_layers = 1
lr = 0.005

encoder1 = EncoderRNN(lang.n_words, hidden_size, n_layers=n_layers).to(device)
decoder1 = AttnDecoderRNN(hidden_size, lang.n_words, dropout_p=0.1, n_layers=n_layers, max_length=MAX_LENGTH).to(device)

epochs = 6

losses_df = trainEvalIters(encoder1, decoder1, epochs, train_dataloader, val_dataloader, eval_every=1000, eval_samples=200, learning_rate=lr)
# Out:
# 3m 4s (- 323m 7s) (1000 0%) Average train loss: 4.3591, Average val loss: 5.3398 ,val BLEU: 0.0000
# 6m 12s (- 322m 20s) (2000 1%) Average train loss: 3.7879, Average val loss: 5.0986 ,val BLEU: 0.0000
# 9m 22s (- 321m 35s) (3000 2%) Average train loss: 3.7794, Average val loss: 4.8481 ,val BLEU: 0.0043
# 12m 30s (- 319m 0s) (4000 3%) Average train loss: 3.7145, Average val loss: 5.3302 ,val BLEU: 0.0000
# 15m 42s (- 317m 5s) (5000 4%) Average train loss: 3.6848, Average val loss: 4.5868 ,val BLEU: 0.0000
# 18m 39s (- 310m 57s) (6000 5%) Average train loss: 3.5507, Average val loss: 4.7057 ,val BLEU: 0.0000
# 21m 41s (- 306m 36s) (7000 6%) Average train loss: 3.5122, Average val loss: 5.3068 ,val BLEU: 0.0000
# 24m 41s (- 302m 15s) (8000 7%) Average train loss: 3.4129, Average val loss: 4.3342 ,val BLEU: 0.0000
# 27m 36s (- 297m 23s) (9000 8%) Average train loss: 3.3719, Average val loss: 4.5461 ,val BLEU: 0.0000
# 30m 38s (- 294m 1s) (10000 9%) Average train loss: 3.4329, Average val loss: 4.6404 ,val BLEU: 0.0000
# 33m 31s (- 289m 24s) (11000 10%) Average train loss: 3.2896, Average val loss: 4.4046 ,val BLEU: 0.0000
# 36m 26s (- 285m 23s) (12000 11%) Average train loss: 3.2591, Average val loss: 4.9796 ,val BLEU: 0.0000
# 39m 22s (- 281m 30s) (13000 12%) Average train loss: 3.2475, Average val loss: 4.8051 ,val BLEU: 0.0053
# 42m 16s (- 277m 40s) (14000 13%) Average train loss: 3.2757, Average val loss: 4.9064 ,val BLEU: 0.0000
# 45m 11s (- 274m 1s) (15000 14%) Average train loss: 3.2950, Average val loss: 4.7168 ,val BLEU: 0.0000
# 48m 8s (- 270m 41s) (16000 15%) Average train loss: 3.2713, Average val loss: 4.6853 ,val BLEU: 0.0000
# 51m 12s (- 267m 56s) (17000 16%) Average train loss: 3.2594, Average val loss: 4.9339 ,val BLEU: 0.0000
# 55m 55s (- 261m 40s) (18660 17%) Average train loss: 5.1883, Average val loss: 4.8454 ,val BLEU: 0.0000
# 58m 54s (- 258m 36s) (19660 18%) Average train loss: 3.1068, Average val loss: 4.5223 ,val BLEU: 0.0000
# 61m 53s (- 255m 30s) (20660 19%) Average train loss: 3.1346, Average val loss: 4.5489 ,val BLEU: 0.0000
# 64m 52s (- 252m 29s) (21660 20%) Average train loss: 3.1818, Average val loss: 4.9235 ,val BLEU: 0.0000
# 67m 49s (- 249m 19s) (22660 21%) Average train loss: 3.0800, Average val loss: 4.4173 ,val BLEU: 0.0015
# 70m 53s (- 246m 35s) (23660 22%) Average train loss: 2.9941, Average val loss: 4.6508 ,val BLEU: 0.0000
# 73m 51s (- 243m 29s) (24660 23%) Average train loss: 3.0764, Average val loss: 5.0686 ,val BLEU: 0.0000
# 76m 52s (- 240m 35s) (25660 24%) Average train loss: 3.1874, Average val loss: 4.6963 ,val BLEU: 0.0000
# 79m 55s (- 237m 44s) (26660 25%) Average train loss: 3.1160, Average val loss: 4.8140 ,val BLEU: 0.0000
# 82m 54s (- 234m 42s) (27660 26%) Average train loss: 3.0679, Average val loss: 4.9488 ,val BLEU: 0.0000
# 85m 48s (- 231m 25s) (28660 27%) Average train loss: 3.0720, Average val loss: 4.4529 ,val BLEU: 0.0000
# 88m 42s (- 228m 11s) (29660 27%) Average train loss: 3.1032, Average val loss: 4.7334 ,val BLEU: 0.0000
# 91m 38s (- 225m 4s) (30660 28%) Average train loss: 3.1458, Average val loss: 4.1925 ,val BLEU: 0.0000
# 94m 33s (- 221m 54s) (31660 29%) Average train loss: 3.1205, Average val loss: 4.5337 ,val BLEU: 0.0035
# 97m 29s (- 218m 49s) (32660 30%) Average train loss: 3.2020, Average val loss: 4.9831 ,val BLEU: 0.0000
# 100m 25s (- 215m 42s) (33660 31%) Average train loss: 3.1074, Average val loss: 5.0990 ,val BLEU: 0.0000
# 103m 21s (- 212m 37s) (34660 32%) Average train loss: 3.1390, Average val loss: 4.8170 ,val BLEU: 0.0000
# 108m 22s (- 207m 47s) (36320 34%) Average train loss: 5.1016, Average val loss: 4.8040 ,val BLEU: 0.0000
# 111m 18s (- 204m 43s) (37320 35%) Average train loss: 2.9307, Average val loss: 4.7106 ,val BLEU: 0.0000
# 114m 11s (- 201m 34s) (38320 36%) Average train loss: 3.0242, Average val loss: 4.3757 ,val BLEU: 0.0042
# 117m 16s (- 198m 45s) (39320 37%) Average train loss: 3.1116, Average val loss: 5.1631 ,val BLEU: 0.0045
# 120m 20s (- 195m 55s) (40320 38%) Average train loss: 3.1038, Average val loss: 4.7306 ,val BLEU: 0.0000
# 123m 23s (- 193m 1s) (41320 38%) Average train loss: 3.1025, Average val loss: 4.8448 ,val BLEU: 0.0000
# 126m 18s (- 189m 56s) (42320 39%) Average train loss: 2.9526, Average val loss: 4.6949 ,val BLEU: 0.0000
# 129m 19s (- 186m 59s) (43320 40%) Average train loss: 3.0243, Average val loss: 4.6045 ,val BLEU: 0.0000
# 132m 19s (- 184m 2s) (44320 41%) Average train loss: 2.9652, Average val loss: 4.4291 ,val BLEU: 0.0000
# 135m 23s (- 181m 8s) (45320 42%) Average train loss: 3.0104, Average val loss: 4.7882 ,val BLEU: 0.0000
# 138m 21s (- 178m 8s) (46320 43%) Average train loss: 3.0455, Average val loss: 4.7311 ,val BLEU: 0.0000
# 141m 15s (- 175m 3s) (47320 44%) Average train loss: 3.0764, Average val loss: 4.6577 ,val BLEU: 0.0000
# 144m 10s (- 171m 58s) (48320 45%) Average train loss: 3.0008, Average val loss: 4.6291 ,val BLEU: 0.0083
# 147m 4s (- 168m 54s) (49320 46%) Average train loss: 2.9404, Average val loss: 4.8976 ,val BLEU: 0.0000
# 150m 3s (- 165m 55s) (50320 47%) Average train loss: 3.0891, Average val loss: 5.1107 ,val BLEU: 0.0000
# 153m 2s (- 162m 56s) (51320 48%) Average train loss: 3.0113, Average val loss: 4.5837 ,val BLEU: 0.0000
# 155m 54s (- 159m 50s) (52320 49%) Average train loss: 3.0189, Average val loss: 4.4713 ,val BLEU: 0.0000
# 160m 48s (- 154m 50s) (53980 50%) Average train loss: 4.9881, Average val loss: 4.6335 ,val BLEU: 0.0000
# 163m 49s (- 151m 54s) (54980 51%) Average train loss: 2.9823, Average val loss: 4.8058 ,val BLEU: 0.0091
# 166m 50s (- 148m 57s) (55980 52%) Average train loss: 3.0587, Average val loss: 4.6477 ,val BLEU: 0.0000
# 169m 44s (- 145m 54s) (56980 53%) Average train loss: 2.9316, Average val loss: 4.7092 ,val BLEU: 0.0083
# 172m 42s (- 142m 55s) (57980 54%) Average train loss: 3.0480, Average val loss: 4.8856 ,val BLEU: 0.0117
# 175m 33s (- 139m 50s) (58980 55%) Average train loss: 2.8664, Average val loss: 4.7303 ,val BLEU: 0.0077
# 178m 25s (- 136m 46s) (59980 56%) Average train loss: 2.9116, Average val loss: 4.7770 ,val BLEU: 0.0091
# 181m 16s (- 133m 43s) (60980 57%) Average train loss: 2.9062, Average val loss: 4.7370 ,val BLEU: 0.0046
# 184m 6s (- 130m 38s) (61980 58%) Average train loss: 2.8472, Average val loss: 4.6786 ,val BLEU: 0.0040
# 187m 1s (- 127m 37s) (62980 59%) Average train loss: 2.9947, Average val loss: 4.6236 ,val BLEU: 0.0000
# 190m 1s (- 124m 40s) (63980 60%) Average train loss: 3.0868, Average val loss: 4.7306 ,val BLEU: 0.0121
# 192m 59s (- 121m 42s) (64980 61%) Average train loss: 3.0088, Average val loss: 4.9586 ,val BLEU: 0.0000
# 195m 54s (- 118m 42s) (65980 62%) Average train loss: 2.9597, Average val loss: 4.8583 ,val BLEU: 0.0058
# 198m 49s (- 115m 42s) (66980 63%) Average train loss: 2.9293, Average val loss: 4.7617 ,val BLEU: 0.0084
# 201m 44s (- 112m 42s) (67980 64%) Average train loss: 2.9548, Average val loss: 4.5351 ,val BLEU: 0.0000
# 204m 39s (- 109m 42s) (68980 65%) Average train loss: 2.9214, Average val loss: 4.9191 ,val BLEU: 0.0000
# 207m 38s (- 106m 45s) (69980 66%) Average train loss: 3.0369, Average val loss: 5.1103 ,val BLEU: 0.0162
# 212m 34s (- 101m 50s) (71640 67%) Average train loss: 4.8596, Average val loss: 4.5726 ,val BLEU: 0.0068
# 215m 33s (- 98m 52s) (72640 68%) Average train loss: 2.7571, Average val loss: 4.8465 ,val BLEU: 0.0122
# 218m 30s (- 95m 54s) (73640 69%) Average train loss: 2.9151, Average val loss: 4.8817 ,val BLEU: 0.0074
# 221m 30s (- 92m 56s) (74640 70%) Average train loss: 2.9076, Average val loss: 4.7766 ,val BLEU: 0.0203
# 224m 28s (- 89m 58s) (75640 71%) Average train loss: 2.9176, Average val loss: 4.7179 ,val BLEU: 0.0130
# 227m 22s (- 86m 59s) (76640 72%) Average train loss: 2.8235, Average val loss: 4.8812 ,val BLEU: 0.0156
# 230m 19s (- 84m 0s) (77640 73%) Average train loss: 2.8479, Average val loss: 4.9187 ,val BLEU: 0.0241
# 233m 13s (- 81m 1s) (78640 74%) Average train loss: 2.8392, Average val loss: 5.1452 ,val BLEU: 0.0168
# 236m 9s (- 78m 2s) (79640 75%) Average train loss: 2.9168, Average val loss: 4.7777 ,val BLEU: 0.0045
# 239m 9s (- 75m 5s) (80640 76%) Average train loss: 2.9914, Average val loss: 5.1077 ,val BLEU: 0.0143
# 242m 7s (- 72m 7s) (81640 77%) Average train loss: 2.8902, Average val loss: 5.0003 ,val BLEU: 0.0175
# 245m 4s (- 69m 9s) (82640 77%) Average train loss: 2.9998, Average val loss: 4.9092 ,val BLEU: 0.0281
# 248m 2s (- 66m 11s) (83640 78%) Average train loss: 2.9689, Average val loss: 4.8260 ,val BLEU: 0.0148
# 250m 58s (- 63m 12s) (84640 79%) Average train loss: 2.8747, Average val loss: 5.0511 ,val BLEU: 0.0112
# 253m 59s (- 60m 15s) (85640 80%) Average train loss: 2.9540, Average val loss: 5.2065 ,val BLEU: 0.0119
# 256m 59s (- 57m 18s) (86640 81%) Average train loss: 2.9314, Average val loss: 5.0246 ,val BLEU: 0.0135
# 259m 55s (- 54m 20s) (87640 82%) Average train loss: 2.8699, Average val loss: 5.0688 ,val BLEU: 0.0154
# 264m 50s (- 49m 24s) (89300 84%) Average train loss: 4.6443, Average val loss: 4.7908 ,val BLEU: 0.0127
# 267m 52s (- 46m 27s) (90300 85%) Average train loss: 2.7625, Average val loss: 4.8918 ,val BLEU: 0.0266
# 270m 51s (- 43m 29s) (91300 86%) Average train loss: 2.7339, Average val loss: 4.7723 ,val BLEU: 0.0344
# 273m 52s (- 40m 31s) (92300 87%) Average train loss: 2.7602, Average val loss: 5.0933 ,val BLEU: 0.0227
# 276m 53s (- 37m 34s) (93300 88%) Average train loss: 2.8114, Average val loss: 5.1652 ,val BLEU: 0.0075
# 279m 55s (- 34m 36s) (94300 88%) Average train loss: 2.8885, Average val loss: 5.3473 ,val BLEU: 0.0288
# 282m 51s (- 31m 38s) (95300 89%) Average train loss: 2.7092, Average val loss: 5.0097 ,val BLEU: 0.0149
# 285m 51s (- 28m 40s) (96300 90%) Average train loss: 2.7591, Average val loss: 5.1685 ,val BLEU: 0.0236
# 288m 44s (- 25m 41s) (97300 91%) Average train loss: 2.7026, Average val loss: 4.9752 ,val BLEU: 0.0197
# 291m 44s (- 22m 44s) (98300 92%) Average train loss: 2.8309, Average val loss: 5.1686 ,val BLEU: 0.0225
# 294m 40s (- 19m 45s) (99300 93%) Average train loss: 2.6991, Average val loss: 5.1713 ,val BLEU: 0.0258
# 297m 43s (- 16m 48s) (100300 94%) Average train loss: 2.8162, Average val loss: 5.0560 ,val BLEU: 0.0311
# 300m 45s (- 13m 50s) (101300 95%) Average train loss: 2.8327, Average val loss: 4.9918 ,val BLEU: 0.0234
# 303m 44s (- 10m 52s) (102300 96%) Average train loss: 2.8187, Average val loss: 5.1927 ,val BLEU: 0.0331
# 306m 42s (- 7m 53s) (103300 97%) Average train loss: 2.8556, Average val loss: 5.1459 ,val BLEU: 0.0404
# 309m 45s (- 4m 55s) (104300 98%) Average train loss: 2.8380, Average val loss: 5.2722 ,val BLEU: 0.0305
# 312m 52s (- 1m 57s) (105300 99%) Average train loss: 2.8638, Average val loss: 4.9046 ,val BLEU: 0.0306

# %%
# Plot losses
losses_df.iloc[:, :-1].plot.line()
# Out:
# <AxesSubplot:>

# %%
losses_df.iloc[:, -1:].plot.line()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Chat with a character
#
# Here is a quick function to manually assess the quality of your translator

# %%
def evaluateRandomly(encoder, decoder, val_dataloader, criterion, n=10):
    for i, sample in enumerate(val_dataloader):
        if i > n: break
        input_tensor = sample['input_tensor'].squeeze()
        target_tensor = sample['target_tensor'].squeeze()
        persona_tensor = sample['persona_tensor'].squeeze()
        
        print('>', ' '.join(lang.getWordsFromIndices(input_tensor.tolist())))
        print('=', ' '.join(lang.getWordsFromIndices(target_tensor.tolist())))
        
        input_tensor = input_tensor.to(device)
        target_tensor = target_tensor.to(device)
        persona_tensor = persona_tensor.to(device)
        decoded_out, _ , _ = evaluate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion)
        
        output_sentence = ' '.join(decoded_out)
        print('<', output_sentence)
        print('')
        
criterion = nn.NLLLoss()
evaluateRandomly(encoder1, decoder1, val_dataloader, criterion)
# Out:
# > phoebe i mean , you just went out with my best friend , and i just think it 'd be a really really bad idea . or-or not ! EOS
# = what ? EOS
# < really ? ,
#
# > what ? phoebe kiss me . phoebe ah , rach , it does n't say that ! EOS
# = no , i 'm saying ... EOS
# < no , i 'm not , i
#
# > do n't know , i don ’ t know what happened , i must be nervous ! phoebe i don ’ t get it , chandler loved it ! EOS
# = ok , ok , ok. i promise , i promise , i promise , i won ’ t do it again . i really do . i promise . EOS
# < i ’ m sorry , i ’ m EOS
#
# > me ! chapter one my first period . phoebe ca n't believe you guys bought that , enjoy your slow death . phoebe i 'm smarter than him ! EOS
# = hey , thank you so much for these tickets , chandler . EOS
# < ooh , i 'm sorry , i 'm sorry , i EOS
#
# > hey rach , can you grab me a cup of coffee ? phoebe sure . phoebe you 've been quiet all morning . is everything okay ? EOS
# = UNK . EOS
# < oh , it
#
# > you UNK $ to get to level three and i do n't feel any different . phoebe pass , pass , oh , pass , UNK , pass ... EOS
# = why , why , what 's wrong with these guys ? EOS
# < oh , it 's so sorry , to . EOS
#
# > i have to sacrifice the most important thing in my life ; my UNK . '' phoebe did that movie ever get made ? phoebe it did not . EOS
# = ross , where are you going ? EOS
# < i can ’ t believe that you ’
#
# > ? phoebe yeah , down from seven hundred , you are saving like two hundred bucks ! phoebe both logic and math are taking a serious hit today . EOS
# = hey , check this out ! it ’ s totally you ! EOS
# < oh my god , you you . EOS
#
# > and what 's the big deal , people do it all the time ! phoebe who ? who do you know that are friends that just fool around ? EOS
# = ok , off the top of my head ... don and UNK . EOS
# < yes ! yes ! yes , i can not believe that , i do
#
# > lovin ' this . phoebe ross .. phoebe it 's all working out ! me & charlie , and you two . you know what we should do ? EOS
# = calm ourselves ? EOS
# < well , i do
#
# > a child halloween costume ! phoebe i may have borrowed this from my UNK , but let me assure you , what 's underneath ... is all man . EOS
# = i 'm sorry , did you say all man or old man ? EOS
# < hey ! ! ! ! ! EOS

# %%
def evaluateManually(encoder, decoder):
    print("chat with", CHOSEN_CHARACTERS)
    print('ENTER to run, Q/q to quit')
    personas = [lang.getIndexFromWord(t) for t in CHOSEN_CHARACTERS]
    
    while True:
        inp = input("You > ")
        print("You >"+inp)
        if inp.lower() == 'q': break
        
        toks = inp.split()[:MAX_LENGTH-1]
        input_tensor = torch.tensor([lang.getIndexFromWord(t) for t in toks] + [EOS_token], dtype=torch.long, device=device)
        for per in personas:
            persona_tensor = torch.tensor(per, dtype=torch.long, device=device)
            decoded_out = generate(input_tensor, None, persona_tensor, encoder, decoder, None)
            print(f"{lang.getWordFromIndex(per)} < {' '.join(decoded_out)}")

evaluateManually(encoder1, decoder1)
# Out:
# chat with {'phoebe', 'rachel'}
# ENTER to run, Q/q to quit
# You >hello
# phoebe < i just thought i was EOS
# rachel < green i ’ m gon na go out with my own ? EOS
# You >
# phoebe < i , i EOS
# rachel < green , i 'm sorry , i 'm sorry . EOS
# You >some pizza?
# phoebe < ow ow ow , i ’ m sorry i that . EOS
# rachel < UNK . EOS
# You >what a disappointment
# phoebe < hey . EOS
# rachel < EOS
# You >
# phoebe < i , i EOS
# rachel < green , i 'm sorry , i 'm sorry . EOS
# You >it's friday
# phoebe < that ’ s great . EOS
# rachel < , i 'm sorry , i EOS
# You >
# phoebe < i , i EOS
# rachel < , i 'm sorry . EOS
# You >that is funny
# phoebe < i , i ! ! EOS
# rachel < , i just wish you could get your back to the wedding . EOS
# You >what wedding?
# phoebe < i 'm sorry , i the that you EOS
# rachel < , the best is she EOS
# You >i am afraid
# phoebe < i don ’ t know what i think i are EOS
# rachel < , i ’ m sorry , i ’ m sorry . i EOS
# You >
# phoebe < i , i EOS
# rachel < , i 'm sorry , i 'm sorry . EOS
# You >weird
# phoebe < i , i EOS
# rachel < , i ’ m sorry . i EOS
# You >phoebe!
# phoebe < i 'm sorry , i EOS
# rachel < i 'm just the best that you were , i 'm sorry , i EOS
# You >
# phoebe < i , i EOS
# rachel < , i ’ m sorry . i EOS
# You >what a moment we just witnessed
# phoebe < that ’ s right . EOS
# rachel < , that ’ s right . EOS
# You >are you okay?
# phoebe < that UNK UNK . EOS
# rachel < UNK the way you were , i 'm just the best , i 'm sorry i the . i EOS
# You >
# phoebe < i , i EOS
# rachel < green , i 'm sorry , i 'm sorry . EOS
# You >how are you feeling?
# phoebe < UNK UNK UNK . EOS
# rachel < UNK the hell i was UNK the best thing i was UNK ? EOS
# You >how are you doing?
# phoebe < UNK UNK the way you were , i 'm sorry , i 'm sorry i ! i ! EOS
# rachel < UNK the best time i was UNK the best thing i was UNK . EOS
# You >i hate you
# phoebe < i do n't have to say i ’ m sorry . . ? i EOS
# rachel < , i ’ m sorry . i ’ m sorry . i ? i EOS
# You >interesting
# phoebe < i ! i EOS
# rachel < i ’ m just gon na ! EOS
# You >bye bye
# phoebe < bye , i EOS
# rachel < i was EOS
# You >
# phoebe < i , i EOS
# rachel < , i 'm just saying that i would n't just say that i 'm not EOS
# You >i am going to sleep
# phoebe < i , you to get to get my EOS
# rachel < , you are so great . EOS
# You >q

# %% [markdown]
# ## Visualize Attention

# %%
import matplotlib.ticker as ticker
def showAttention(input_words, output_words, attentions):
    # Set up figure with colorbar
    fig = plt.figure()
    ax = fig.add_subplot(111)
    cax = ax.matshow(attentions.numpy(), cmap='bone')
    fig.colorbar(cax)

    # Set up axes
    ax.set_xticklabels([''] + input_words, rotation=90)
    ax.set_yticklabels([''] + output_words)

    # Show label at every tick
    ax.xaxis.set_major_locator(ticker.MultipleLocator(1))
    ax.yaxis.set_major_locator(ticker.MultipleLocator(1))

    plt.show()

def evaluateRandomlyAndShowAttention(encoder, decoder, val_dataloader, criterion):
    sample = next(iter(val_dataloader))
    
    input_words = lang.getWordsFromIndices(sample['input_tensor'].squeeze().tolist())
    input_tensor = sample['input_tensor'].squeeze().to(device)
    target_tensor = sample['target_tensor'].squeeze().to(device)
    persona_tensor = sample['person_tensor'].squeeze().to(device)
    output_words, _, attention = evaluate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion)
    print('input : ', ' '.join(input_words))
    print('predicted :', ' '.join(output_words))
    showAttention(input_words, output_words, attention)

criterion = nn.NLLLoss()
evaluateRandomlyAndShowAttention(encoder1, decoder1, val_dataloader, criterion)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_21221/96747033.py in <module>
#      30
#      31 criterion = nn.NLLLoss()
# ---> 32 evaluateRandomlyAndShowAttention(encoder1, decoder1, val_dataloader, criterion)
#
# /tmp/ipykernel_21221/96747033.py in evaluateRandomlyAndShowAttention(encoder, decoder, val_dataloader, criterion)
#      23     input_tensor = sample['input_tensor'].squeeze().to(device)
#      24     target_tensor = sample['target_tensor'].squeeze().to(device)
# ---> 25     persona_tensor = sample['person_tensor'].squeeze().to(device)
#      26     output_words, _, attention = evaluate(input_tensor, target_tensor, persona_tensor, encoder, decoder, criterion)
#      27     print('input : ', ' '.join(input_words))
#
# KeyError: 'person_tensor'
